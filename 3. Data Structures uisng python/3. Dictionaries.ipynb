# %%
## Dictionary Comprehsension
squares= {x:x**2 for x in range(5)}
squares
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
sq

# %%
for i in student:
    print(student[i])
# Out:
# KrishNaik
# 32

# %%
for key, values in student.items():
    print(key , values)
# Out:
# Name KrishNaik
# age 32

# %%
studnents= {
    "student1": {"name": "krish", "age":32},
    "studnet2": {"name": "peter", "age": 35}

}

studnents['student1']['name']
# Out:
# 'krish'

# %%
Keys=student.keys()
print(Keys)
values=student.values()
print(values)
items=student.items()
print(items)

ABC=student.copy()
# Out:
# dict_keys(['Name', 'age'])
# dict_values(['KrishNaik', 32])
# dict_items([('Name', 'KrishNaik'), ('age', 32)])

# %%
del student['Grade']

# %%
student.get('name', "Not avaia")
# Out:
# 'Not avaia'

# %%
student.get('Grade')
# Out:
# 24

# %%
student['Name']
# Out:
# 'KrishNaik'

# %%
student={"Name": "KrishNaik", "age":32, "Grade": 24
         }
student
# Out:
# {'Name': 'KrishNaik', 'age': 32, 'Grade': 24}

# %%
Dictionary
# Out:
# {}

# %%
Dictionary={
    
}

type(Dictionary)
# Out:
# dict
