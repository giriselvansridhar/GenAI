# %%
## Immputable

# %%
Tuple=()
Tuple=tuple()
print(Tuple)
print(type(Tuple))
# Out:
# ()
# <class 'tuple'>

# %%
number = tuple([1,2,3,4,5,6])
number
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
number = (1, "String", 43434.34, True)
number
# Out:
# (1, 'String', 43434.34, True)

# %%
## Acessing tuple elements
print(number[2])
print(number[-1])
# Out:
# 43434.34
# True

# %%
number [1:4:1]
# Out:
# ('String', 43434.34, True)

# %%
Concadinattion= number + number
Concadinattion
# Out:
# (1, 'String', 43434.34, True, 1, 'String', 43434.34, True)

# %%
print(number.count(1
                   ))
print(number.index('String'))
# Out:
# 2
# 1

# %%
Packed_Tuple= 1, "Hello", 2 , 4,5,6,7

# %%
a,b,c=Packed_Tuple
print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 2

# %%
a, *b, c = Packed_Tuple
print(a)
print(b)
print(c)
# Out:
# 1
# ['Hello', 2, 4, 5, 6]
# 7

# %%
## Nested List
## Nested List
