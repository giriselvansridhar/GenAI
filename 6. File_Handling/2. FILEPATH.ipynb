# %%
import os
path= "example.txt"
if os.path.exists(path):
    print("Exisits")
# Out:
# Exisits

# %%
relative_path= "ExAMPLE"

absolute_path=os.path.abspath(relative_path)
absolute_path
# Out:
# 'c:\\Users\\giris\\Desktop\\GenAI with Langchain\\6. File_Handling\\ExAMPLE'

# %%
## Joining Paths
import os
dir_name="folder"
full_name= "file.txt"
relative=os.getcwd()

fullpath=os.path.join(relative,dir_name,full_name)
print(fullpath)
# Out:
# c:\Users\giris\Desktop\GenAI with Langchain\6. File_Handling\folder\file.txt

# %%
## List files and Directionat

items= os.listdir('.')
for i in items:
    print(i)
# Out:
# 2. FILEPATH.ipynb
# Binar.bn
# example.txt
# fileoperations.ipynb
# New Folder

# %%
import os

# %%
import os
os.mkdir("New Folder")
