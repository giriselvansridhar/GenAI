# %%
import math

math.sqrt(
    16
)
# Out:
# 4.0

# %%
from math import sqrt, pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import * 
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.maths import sub13
addition(2,3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 from package.maths import sub13
#       2 addition(2,3)
#
# ImportError: cannot import name 'sub13' from 'package.maths' (c:\Users\giris\Desktop\GenAI with Langchain\5. Importing , Creating Modules and Packages\package\maths.py)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 substraction(3,4)
#
# NameError: name 'substraction' is not defined
