# %%
age=18
if age >18:
    print("You are allwoed to vote in the elecgtions")
elif age==18:
    print("Apply for voter it")   
elif age < 100:
    print("You are too old")     
else:
    print("You are not allowed to participant in the election")
# Out:
# Apply for voter it

# %%
## Into to conditional Statements
## IF Statements
## Else Statements
## Elif Statements
## Nested Conditioanl Statemenent

# %%
## Nested Conditional Statmene

## number even, odd, neagative



num=int(input("Enter the number"))
if num>=0:
    print("This is a positivr Number")

    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")


else:
    print("The number is neagative")
# Out:
# The number is neagative

# %%
## Practical Example


## Determine if year is leap year using nested contional stataments

year = int (input("Enter the year"))
if year%4==0:
    if year%400==0:
        print(year, "is a leap year")
    else:
        print(year,"is not a leap year")
else:
    print(year, "is a leap year")

# %%
Num1=float(input("Enter the number 1"))
