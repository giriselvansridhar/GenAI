# %%
##Map() - Applies a function to all items in a list

numbers = [1,2,3,4,5,6]
def square(number):
    return number**2

square(2)
# Out:
# 4

# %%
list(map(lambda x: x**2, numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
Even = lambda num: num%2==0

# %%
Addition = lambda a,b,c: a+b+c

Addition(1,2,3)
# Out:
# 6

# %%
def addition(a,b):
    return a+b


## If I have one fucntion create a lamamda function

addition = lambda a,b: a+b

type(addition)

addition(5,6)
# Out:
# 11

# %%
## Lamada Function
