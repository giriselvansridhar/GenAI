# %%
## Use map() to convet the list of string to integrs
str= ['1', '2', '3', '4']

interger_numbers=list(map(int ,str))
interger_numbers
# Out:
# [1, 2, 3, 4]

# %%
### Map Mutiple Interables
numbers1=[1,2,4]
numbers2=[2,3,4]
added=list(map(lambda x,y:x+y, numbers1, numbers2))

# %%
## Lamada Function with map

numbers= [1,2,3,4,5,6,7,8]

list(map(lambda x:x*x , numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
def square (x):
    return x*x

# %%
numbers=[1,2,3,4,5,6,7,8]

list(map(square, numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]
