# %%
a=100

# %%
## Declaring A variabel
age=32
height=6.2
name="Krish"
is_student=True

## Prinitng

print("Age:",age)
print("Height:",height)
print("Name:", name)
# Out:
# Age: 32
# Height: 6.2
# Name: Krish

# %%
## Naming Convertions
## Variable name should be descriptive
## They must start with a letter or an "_" and contains numbers, numbers  and underscores
## Variables are case sensitive


first_name="Krish Naik"

# %%
## Invalid Variales
#12age=30
#first-name="Krsish"
##@name="Krish"

# %%
## Understading Vatiable Types
## Python is dynaic typed, type of the varuabke is determined at runtime

age=25
height=6.1 
name="Krish"
is_student=True
print(type(is_student))
# Out:
# <class 'bool'>

# %%
## Type Checking and conversion

type(height)
# Out:
# float

# %%
age=25
print(type(age))
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
## int -> float
## string (Name) --> not int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 name="Krish"
# ----> 3 int (name)
#
# ValueError: invalid literal for int() with base 10: 'Krish'

# %%
## Dynamic Typig
## Python allows the type of a variable to change as the program executes
var=10
print(var, type(var))
# Out:
# 10 <class 'int'>

# %%
## input

age = int(input ("What is the age ?"))

# %%
print(age, type(age))
# Out:
# 23 <class 'int'>

# %%
num1=float(input("Enter the number1: "))
num2=float(input("Enter the number 2:"))
print("Sum: ", num1+num2)
print("Diff: ", num1-num2)
print("Multiplication ",num1 *num2)
print("Division :", num1 / num2)
# Out:
# Sum:  7.0
# Diff:  -1.0
# Multiplication  12.0
# Division : 0.75
