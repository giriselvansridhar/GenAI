# %%
type(b)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
## Understand Semantic in python
#variale assignment

a=10
b="Kris"

# %%
## Mutiple statment on a single line
x=5; y=10; z=x+y
print(z)
# Out:
# 15

# %%
## Line Contiuation. Can use \ to continur 

total = 1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Indentation
## Python uses identation to define block of code. Conssistency use of spaces. (commonly 4) or a tab is required

age=32
if age > 30:
    print(age)     
print(age)
# Out:
# 32
# 32

# %%
##1. Python is case sensisive
name="Krish"
Name="Naik"
print(name)
print(Name)
# Out:
# Krish
# Naik

# %%
## Basic Syntax Rules in Python
## Case Sensitivity


'''

Mutiline. Not work in the Jypiter Notebook

'''
# Out:
# '\n\nMutiline. Not work in the Jypiter Notebook\n\n'
